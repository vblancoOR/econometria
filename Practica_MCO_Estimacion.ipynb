# %% [markdown]
# <a href="https://colab.research.google.com/github/vblancoOR/econometria/blob/main/Practica_MCO_Estimacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #librería para manejo de datos

datos= pd.read_csv("https://rtgodwin.com/data/houseprice.csv") #Lee base de datos de web...

datos.columns
# Out:
# Index(['Price', 'Lot.Size', 'Waterfront', 'Age', 'Land.Value', 'New.Construct',
#        'Central.Air', 'Fuel.Type', 'Heat.Type', 'Sewer.Type', 'Living.Area',
#        'Pct.College', 'Bedrooms', 'Fireplaces', 'Bathrooms', 'Rooms'],
#       dtype='object')

# %%
import statsmodels.api as sm


y = datos["Price"]
X = datos[['Lot.Size', 'Waterfront', 'Age', 'Land.Value', 'New.Construct',
       'Central.Air', 'Living.Area',
       'Pct.College', 'Bedrooms', 'Fireplaces', 'Bathrooms', 'Rooms']]

mco = sm.OLS(y, sm.add_constant(X)).fit()

print(mco.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.651
# Model:                            OLS   Adj. R-squared:                  0.649
# Method:                 Least Squares   F-statistic:                     266.6
# Date:                Tue, 15 Oct 2024   Prob (F-statistic):               0.00
# Time:                        18:07:45   Log-Likelihood:                -21409.
# No. Observations:                1728   AIC:                         4.284e+04
# Df Residuals:                    1715   BIC:                         4.292e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.798e+04   9582.728      1.877      0.061    -811.728    3.68e+04
# ...

# %%
datos
# Out:
#        Price  Lot.Size  Waterfront  Age  Land.Value  New.Construct  \
# 0     132500      0.09           0   42       50000              0
# 1     181115      0.92           0    0       22300              0
# 2     109000      0.19           0  133        7300              0
# 3     155000      0.41           0   13       18700              0
# 4      86060      0.11           0    0       15000              1
# ...      ...       ...         ...  ...         ...            ...
# 1723  289000      0.38           0   32       24200              0
# 1724  285000      0.94           0   37       36200              0
# 1725  194900      0.39           0    9       20400              0
# 1726  125000      0.24           0   48       16800              0
# 1727  111300      0.59           0   86       26000              0
#
#       Central.Air Fuel.Type  Heat.Type Sewer.Type  Living.Area  Pct.College  \
# 0               0  Electric   Electric    Private          906           35
# ...

# %%
import numpy as np

datos["logPrecio"] = np.log(datos["Price"])
datos["logLandValue"] = np.log(datos["Land.Value"])

# %%
y = datos["logPrecio"]
X = datos[['Lot.Size', 'Waterfront', 'Age', 'Land.Value', 'New.Construct',
       'Central.Air', 'Living.Area',
       'Pct.College', 'Bedrooms', 'Fireplaces', 'Bathrooms', 'Rooms']]

mco = sm.OLS(y, sm.add_constant(X)).fit()

print(mco.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              logPrecio   R-squared:                       0.579
# Model:                            OLS   Adj. R-squared:                  0.576
# Method:                 Least Squares   F-statistic:                     196.9
# Date:                Tue, 15 Oct 2024   Prob (F-statistic):          7.55e-312
# Time:                        18:24:17   Log-Likelihood:                -333.99
# No. Observations:                1728   AIC:                             694.0
# Df Residuals:                    1715   BIC:                             764.9
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            11.1634      0.048    230.713      0.000      11.069      11.258
# ...

# %%
y = datos["Price"]
X = datos[['Lot.Size', 'Waterfront', 'Age', 'logLandValue', 'New.Construct',
       'Central.Air', 'Living.Area',
       'Pct.College', 'Bedrooms', 'Fireplaces', 'Bathrooms', 'Rooms']]

mco = sm.OLS(y, sm.add_constant(X)).fit()

print(mco.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.620
# Model:                            OLS   Adj. R-squared:                  0.617
# Method:                 Least Squares   F-statistic:                     233.0
# Date:                Tue, 15 Oct 2024   Prob (F-statistic):               0.00
# Time:                        18:31:21   Log-Likelihood:                -21483.
# No. Observations:                1728   AIC:                         4.299e+04
# Df Residuals:                    1715   BIC:                         4.306e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -1.908e+05   1.57e+04    -12.123      0.000   -2.22e+05    -1.6e+05
# ...

# %%
y = datos["logPrecio"]
X = datos[['Lot.Size', 'Waterfront', 'Age', 'logLandValue', 'New.Construct',
       'Central.Air', 'Living.Area',
       'Pct.College', 'Bedrooms', 'Fireplaces', 'Bathrooms', 'Rooms']]

mco = sm.OLS(y, sm.add_constant(X)).fit()

print(mco.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              logPrecio   R-squared:                       0.580
# Model:                            OLS   Adj. R-squared:                  0.577
# Method:                 Least Squares   F-statistic:                     197.4
# Date:                Tue, 15 Oct 2024   Prob (F-statistic):          2.25e-312
# Time:                        18:34:27   Log-Likelihood:                -332.76
# No. Observations:                1728   AIC:                             691.5
# Df Residuals:                    1715   BIC:                             762.4
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            10.2069      0.076    134.159      0.000      10.058      10.356
# ...

# %%
datos.columns
# Out:
# Index(['Price', 'Lot.Size', 'Waterfront', 'Age', 'Land.Value', 'New.Construct',
#        'Central.Air', 'Fuel.Type', 'Heat.Type', 'Sewer.Type', 'Living.Area',
#        'Pct.College', 'Bedrooms', 'Fireplaces', 'Bathrooms', 'Rooms',
#        'logPrecio', 'logLandValue'],
#       dtype='object')

# %%
dummies = pd.get_dummies(datos["Fuel.Type"], dtype="int", drop_first=True)
datos = pd.concat([datos, dummies], axis=1)
dummies = pd.get_dummies(datos["Heat.Type"], dtype="int", drop_first=True)
datos = pd.concat([datos, dummies], axis=1)
dummies = pd.get_dummies(datos["Sewer.Type"], dtype="int", drop_first=True)
datos = pd.concat([datos, dummies], axis=1)

datos
# Out:
#        Price  Lot.Size  Waterfront  Age  Land.Value  New.Construct  \
# 0     132500      0.09           0   42       50000              0
# 1     181115      0.92           0    0       22300              0
# 2     109000      0.19           0  133        7300              0
# 3     155000      0.41           0   13       18700              0
# 4      86060      0.11           0    0       15000              1
# ...      ...       ...         ...  ...         ...            ...
# 1723  289000      0.38           0   32       24200              0
# 1724  285000      0.94           0   37       36200              0
# 1725  194900      0.39           0    9       20400              0
# 1726  125000      0.24           0   48       16800              0
# 1727  111300      0.59           0   86       26000              0
#
#       Central.Air Fuel.Type  Heat.Type Sewer.Type  ...  Bathrooms  Rooms  \
# 0               0  Electric   Electric    Private  ...        1.0      5
# ...

# %%
datos.columns
# Out:
# Index(['Price', 'Lot.Size', 'Waterfront', 'Age', 'Land.Value', 'New.Construct',
#        'Central.Air', 'Fuel.Type', 'Heat.Type', 'Sewer.Type', 'Living.Area',
#        'Pct.College', 'Bedrooms', 'Fireplaces', 'Bathrooms', 'Rooms',
#        'logPrecio', 'logLandValue', 'Gas', 'Oil', 'Hot Air', 'Hot Water',
#        'Private', 'Public'],
#       dtype='object')

# %%
y = datos["Price"]
X = datos[['Lot.Size', 'Waterfront', 'Age', 'Land.Value', 'New.Construct',
       'Central.Air', 'Living.Area',
       'Pct.College', 'Bedrooms', 'Fireplaces', 'Bathrooms', 'Rooms', 'Gas', 'Oil', 'Hot Air', 'Hot Water',
       'Private', 'Public']]

mco = sm.OLS(y, sm.add_constant(X)).fit()

print(mco.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.653
# Model:                            OLS   Adj. R-squared:                  0.650
# Method:                 Least Squares   F-statistic:                     179.0
# Date:                Tue, 15 Oct 2024   Prob (F-statistic):               0.00
# Time:                        18:44:27   Log-Likelihood:                -21403.
# No. Observations:                1728   AIC:                         4.284e+04
# Df Residuals:                    1709   BIC:                         4.295e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          9258.7471   1.96e+04      0.472      0.637   -2.92e+04    4.77e+04
# ...
