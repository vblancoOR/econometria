# %% [markdown]
# # Practica 1: Econometría 2024-2025

# %%
import pandas as pd #librería para manejo de datos

datos = pd.read_csv("https://rtgodwin.com/data/houseprice.csv") #Lee base
datos
# Out:
#        Price  Lot.Size  Waterfront  Age  Land.Value  New.Construct  \
# 0     132500      0.09           0   42       50000              0
# 1     181115      0.92           0    0       22300              0
# 2     109000      0.19           0  133        7300              0
# 3     155000      0.41           0   13       18700              0
# 4      86060      0.11           0    0       15000              1
# ...      ...       ...         ...  ...         ...            ...
# 1723  289000      0.38           0   32       24200              0
# 1724  285000      0.94           0   37       36200              0
# 1725  194900      0.39           0    9       20400              0
# 1726  125000      0.24           0   48       16800              0
# 1727  111300      0.59           0   86       26000              0
#
#       Central.Air Fuel.Type  Heat.Type Sewer.Type  Living.Area  Pct.College  \
# 0               0  Electric   Electric    Private          906           35
# 1               0       Gas  Hot Water    Private         1953           51
# 2               0       Gas  Hot Water     Public         1944           51
# 3               0       Gas    Hot Air    Private         1944           51
# 4               1       Gas    Hot Air     Public          840           51
# ...           ...       ...        ...        ...          ...          ...
# 1723            0       Gas  Hot Water     Public         2310           61
# 1724            0       Gas  Hot Water     Public         2564           61
# 1725            0       Gas    Hot Air     Public         1099           51
# 1726            0       Gas    Hot Air     Public         1225           51
# 1727            0       Gas    Hot Air    Private         1959           51
#
#       Bedrooms  Fireplaces  Bathrooms  Rooms
# 0            2           1        1.0      5
# 1            3           0        2.5      6
# 2            4           1        1.0      8
# 3            3           1        1.5      5
# 4            2           0        1.0      3
# ...        ...         ...        ...    ...
# 1723         5           1        2.5     11
# 1724         4           1        2.5     11
# 1725         2           0        1.0      3
# 1726         3           1        1.0      7
# 1727         3           0        1.0      6
#
# [1728 rows x 16 columns]

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1728 non-null   int64
#  1   Lot.Size       1728 non-null   float64
#  2   Waterfront     1728 non-null   int64
#  3   Age            1728 non-null   int64
#  4   Land.Value     1728 non-null   int64
#  5   New.Construct  1728 non-null   int64
#  6   Central.Air    1728 non-null   int64
#  7   Fuel.Type      1728 non-null   object
#  8   Heat.Type      1728 non-null   object
#  9   Sewer.Type     1728 non-null   object
#  10  Living.Area    1728 non-null   int64
#  11  Pct.College    1728 non-null   int64
#  12  Bedrooms       1728 non-null   int64
#  13  Fireplaces     1728 non-null   int64
#  14  Bathrooms      1728 non-null   float64
#  15  Rooms          1728 non-null   int64
# dtypes: float64(2), int64(11), object(3)
# memory usage: 216.1+ KB

# %%
datos["Fuel.Type"].value_counts()
# Out:
# Fuel.Type
# Gas         1197
# Electric     315
# Oil          216
# Name: count, dtype: int64

# %%
datos["Price"].value_counts()
# Out:
# Price
# 150000    21
# 225000    21
# 120000    21
# 155000    19
# 195000    18
#           ..
# 470000     1
# 164400     1
# 362710     1
# 381500     1
# 111300     1
# Name: count, Length: 751, dtype: int64

# %%
precios=datos["Price"]

# %%
precios
# Out:
# 0       132500
# 1       181115
# 2       109000
# 3       155000
# 4        86060
#          ...
# 1723    289000
# 1724    285000
# 1725    194900
# 1726    125000
# 1727    111300
# Name: Price, Length: 1728, dtype: int64

# %%
precios.mean()
# Out:
# 211966.7054398148

# %%
 precios.min()
# Out:
# 5000

# %%
precios.max()
# Out:
# 775000

# %%
precios.max()-precios.min()
# Out:
# 770000

# %%
precios.median()
# Out:
# 189900.0

# %%
precios.quantile(0.25)
# Out:
# 145000.0

# %%
precios.quantile(0.75)
# Out:
# 259000.0

# %%
precios.quantile(0.75)-precios.quantile(0.25)
# Out:
# 114000.0

# %%
precios.var()
# Out:
# 9690707465.040573

# %%
precios.std()
# Out:
# 98441.39101536799

# %%
precios.mode()
# Out:
# 0    120000
# 1    150000
# 2    225000
# Name: Price, dtype: int64

# %%
precios.describe()
# Out:
# count      1728.000000
# mean     211966.705440
# std       98441.391015
# min        5000.000000
# 25%      145000.000000
# 50%      189900.000000
# 75%      259000.000000
# max      775000.000000
# Name: Price, dtype: float64

# %%
import seaborn as sns

sns.histplot(precios, kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
precios.skew()
# Out:
# 1.5777134366217407

# %%
precios.kurtosis()
# Out:
# 4.191532076249885

# %%
sns.boxplot(precios)
# Out:
# <Axes: ylabel='Price'>

# %%
combustible=datos["Fuel.Type"]

# %%
combustible
# Out:
# 0       Electric
# 1            Gas
# 2            Gas
# 3            Gas
# 4            Gas
#           ...
# 1723         Gas
# 1724         Gas
# 1725         Gas
# 1726         Gas
# 1727         Gas
# Name: Fuel.Type, Length: 1728, dtype: object

# %%
combustible.value_counts()
# Out:
# Fuel.Type
# Gas         1197
# Electric     315
# Oil          216
# Name: count, dtype: int64

# %%
sns.histplot(combustible, stat="percent")
# Out:
# <Axes: xlabel='Fuel.Type', ylabel='Percent'>

# %%
dumis_nuevas= pd.get_dummies(combustible)

# %%
datos = pd.concat([datos, dumis_nuevas], axis=1)

# %%
datos
# Out:
#        Price  Lot.Size  Waterfront  Age  Land.Value  New.Construct  \
# 0     132500      0.09           0   42       50000              0
# 1     181115      0.92           0    0       22300              0
# 2     109000      0.19           0  133        7300              0
# 3     155000      0.41           0   13       18700              0
# 4      86060      0.11           0    0       15000              1
# ...      ...       ...         ...  ...         ...            ...
# 1723  289000      0.38           0   32       24200              0
# 1724  285000      0.94           0   37       36200              0
# 1725  194900      0.39           0    9       20400              0
# 1726  125000      0.24           0   48       16800              0
# 1727  111300      0.59           0   86       26000              0
#
#       Central.Air Fuel.Type  Heat.Type Sewer.Type  Living.Area  Pct.College  \
# 0               0  Electric   Electric    Private          906           35
# 1               0       Gas  Hot Water    Private         1953           51
# 2               0       Gas  Hot Water     Public         1944           51
# 3               0       Gas    Hot Air    Private         1944           51
# 4               1       Gas    Hot Air     Public          840           51
# ...           ...       ...        ...        ...          ...          ...
# 1723            0       Gas  Hot Water     Public         2310           61
# 1724            0       Gas  Hot Water     Public         2564           61
# 1725            0       Gas    Hot Air     Public         1099           51
# 1726            0       Gas    Hot Air     Public         1225           51
# 1727            0       Gas    Hot Air    Private         1959           51
#
#       Bedrooms  Fireplaces  Bathrooms  Rooms  Electric    Gas    Oil
# 0            2           1        1.0      5      True  False  False
# 1            3           0        2.5      6     False   True  False
# 2            4           1        1.0      8     False   True  False
# 3            3           1        1.5      5     False   True  False
# 4            2           0        1.0      3     False   True  False
# ...        ...         ...        ...    ...       ...    ...    ...
# 1723         5           1        2.5     11     False   True  False
# 1724         4           1        2.5     11     False   True  False
# 1725         2           0        1.0      3     False   True  False
# 1726         3           1        1.0      7     False   True  False
# 1727         3           0        1.0      6     False   True  False
#
# [1728 rows x 19 columns]
